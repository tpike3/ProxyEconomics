# %%
import pickle
import pandas as pd

# %%
data = pickle.load( open( "data.pkl", "rb" ) )

# %%
data.head()
# Out:
#    Step    AgentID    Proxy     Goal  Goal_oc  Utility Effort  Practice  \
# 0     1  Company_0     none     none     none     none   none      none
# 1     1        100  6.90972  9.99745  7.22881  15.8906     10  0.194263
# 2     1         99  6.92868  9.99801  7.21064  15.3359     10  0.805337
# 3     1         98  7.27002  9.99593  6.86635  14.6298     10  0.756851
# 4     1         97  6.94889  9.99853  7.19117  15.7225     10   0.80253
#
#   Genealogy   Talent  Run
# 0      none     none    0
# 1        11  9.66882    0
# 2        99  9.84967    0
# 3        98   9.0155    0
# 4        97  10.2237    0

# %%
company = data[data["Effort"] == "none"]

# %%
company.head()
# Out:
#     Step    AgentID Proxy  Goal Goal_oc Utility Effort Practice Genealogy  \
# 0      1  Company_0  none  none    none    none   none     none      none
# 11     1  Company_1  none  none    none    none   none     none      none
# 22     1  Company_2  none  none    none    none   none     none      none
# 33     1  Company_3  none  none    none    none   none     none      none
# 44     1  Company_4  none  none    none    none   none     none      none
#
#    Talent  Run
# 0    none    0
# 11   none    0
# 22   none    0
# 33   none    0
# 44   none    0

# %%
data = data[data['Effort']!= "none"]
data.reset_index(drop=True)
del data['index']
data.head()
# Out:
#    Step AgentID    Proxy     Goal  Goal_oc  Utility Effort  Practice  \
# 0     1     100  6.90972  9.99745  7.22881  15.8906     10  0.194263
# 1     1      99  6.92868  9.99801  7.21064  15.3359     10  0.805337
# 2     1      98  7.27002  9.99593  6.86635  14.6298     10  0.756851
# 3     1      97  6.94889  9.99853  7.19117  15.7225     10   0.80253
# 4     1      96  6.91615  9.99765  7.22266  17.0809     10  0.807073
#
#   Genealogy   Talent  Run
# 0        11  9.66882    0
# 1        99  9.84967    0
# 2        98   9.0155    0
# 3        97  10.2237    0
# 4        96  11.9073    0
